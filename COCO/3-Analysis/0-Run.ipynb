# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from Worker import aggregate_pairs, aggregate_trials, show_pairs, make_tex

# %%
os.system('rm -rf ./Results')
os.system('mkdir ./Results')

modes = {'initial-tune': 'Baseline', 'SPIRE': 'SPIRE', 'fs-tune-ptune': 'FS'}
trials = [0,1,2,3,4,5,6,7]

corrected = {'SPIRE': 'SPIRE', 'fs-tune-ptune': 'FS'}
baseline = 'initial-tune'

# Generate the results per pair (averaged across trials first)
aggregate_pairs(modes, trials)
make_tex(['Baseline', 'SPIRE'])

# Generate the results across trials (aggregate over pairs first)
aggregate_trials(corrected, baseline, trials)

# %%
show_pairs('SPIRE', 'Baseline')
# Out:
# Aggregate Differences:
# both
# mean (std): -0.057 0.111
# median: -0.062
# prob > 0: 0.31
# just_main
# mean (std): 0.018 0.063
# median: 0.017
# prob > 0: 0.586
# just_spurious
# mean (std): -0.003 0.034
# median: 0.002
# prob > 0: 0.655
# neither
# mean (std): -0.0 0.002
# median: -0.0
# prob > 0: 0.31
# b-precision
# mean (std): -0.006 0.114
# median: 0.022
# prob > 0: 0.69
# b-recall
# mean (std): -0.02 0.057
# median: -0.031
# prob > 0: 0.379
# r-gap
# mean (std): -0.086 0.127
# median: -0.08
# prob < 0: 0.759
# h-gap
# mean (std): 0.002 0.032
# median: -0.003
# prob < 0: 0.759

# %%
show_pairs('FS', 'Baseline')
# Out:
# Aggregate Differences:
# both
# mean (std): -0.102 0.082
# median: -0.081
# prob > 0: 0.0
# just_main
# mean (std): -0.092 0.081
# median: -0.078
# prob > 0: 0.069
# just_spurious
# mean (std): 0.011 0.023
# median: 0.002
# prob > 0: 0.69
# neither
# mean (std): 0.002 0.003
# median: 0.001
# prob > 0: 0.793
# b-precision
# mean (std): 0.022 0.104
# median: 0.019
# prob > 0: 0.586
# b-recall
# mean (std): -0.097 0.07
# median: -0.088
# prob > 0: 0.034
# r-gap
# mean (std): -0.015 0.063
# median: 0.004
# prob < 0: 0.483
# h-gap
# mean (std): -0.009 0.022
# median: -0.0
# prob < 0: 0.552
